# %% [markdown]
# <a href="https://colab.research.google.com/github/Supriyadandawate/30-Days-of-Python-programming/blob/main/Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modules in python
#
#
# *   Math
# *   Keyword
# *   random
# *   Datetime

# %%
import math

# %%
math.factorial(9)
# Out:
# 362880

# %%
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
# keyword
import keyword
print(len(keyword.kwlist))
# Out:
# 35

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 93

# %%
from  datetime import date

# %%
today = date.today()
print("Todays date is:", today)
# Out:
# Todays date is: 2025-01-13

# %%
from datetime import datetime

# Current date and time
now = datetime.now()
print("Current Date and Time:", now)
# Out:
# Current Date and Time: 2025-01-13 05:44:51.990098
